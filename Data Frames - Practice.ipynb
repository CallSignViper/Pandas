# %% [markdown]
# ### Shared Methods and Attributes with Series

# %%
import pandas as pd

# %%
nba = pd.read_csv('nba.csv')

# %%
nba.head(7)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0
# 6                LSU   1170960.0

# %%
nba.tail(5)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.get_dtype_counts()
# Out:
# float64    4
# object     5
# dtype: int64

# %% [markdown]
# ### Differences between Shared Methods

# %%
rev = pd.read_csv('revenue.csv', index_col= 'Date')
rev.head(3)
# Out:
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933

# %%
s = pd.Series([1,2,3])
s
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s.sum()
# Out:
# 6

# %%
rev.sum()
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
rev.sum(axis = "index")
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
rev.sum(axis = 1)
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
rev.sum(axis = "columns")
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %% [markdown]
# ### Select One Column from a DataFrame

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.Salary

Output = None

# %%
nba["Name"].head(5)
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# Name: Name, dtype: object

# %%
nba["Team"].head(5)
# Out:
# 0    Boston Celtics
# 1    Boston Celtics
# 2    Boston Celtics
# 3    Boston Celtics
# 4    Boston Celtics
# Name: Team, dtype: object

# %%
type(nba["Name"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Selefct Tow or More Columns from A DataFrame

# %%
nba[["Name","Team"]].head()
# Out:
#             Name            Team
# 0  Avery Bradley  Boston Celtics
# 1    Jae Crowder  Boston Celtics
# 2   John Holland  Boston Celtics
# 3    R.J. Hunter  Boston Celtics
# 4  Jonas Jerebko  Boston Celtics

# %%
nba[["Team","Name"]].head(3)
# Out:
#              Team           Name
# 0  Boston Celtics  Avery Bradley
# 1  Boston Celtics    Jae Crowder
# 2  Boston Celtics   John Holland

# %%
nba[['Number','College']].head()
# Out:
#    Number            College
# 0     0.0              Texas
# 1    99.0          Marquette
# 2    30.0  Boston University
# 3    28.0      Georgia State
# 4     8.0                NaN

# %%
nba[['Salary','Team','Name']].head()
# Out:
#       Salary            Team           Name
# 0  7730337.0  Boston Celtics  Avery Bradley
# 1  6796117.0  Boston Celtics    Jae Crowder
# 2        NaN  Boston Celtics   John Holland
# 3  1148640.0  Boston Celtics    R.J. Hunter
# 4  5000000.0  Boston Celtics  Jonas Jerebko

# %%
select = ['Salary','Team','Name']
nba[select].head()
# Out:
#       Salary            Team           Name
# 0  7730337.0  Boston Celtics  Avery Bradley
# 1  6796117.0  Boston Celtics    Jae Crowder
# 2        NaN  Boston Celtics   John Holland
# 3  1148640.0  Boston Celtics    R.J. Hunter
# 4  5000000.0  Boston Celtics  Jonas Jerebko

# %% [markdown]
# ### Add New Column to DataFrame

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba["Sport"] = "Basketball"

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball

# %%
nba["League"] = "National Basketball Association"
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport                           League
# 0              Texas  7730337.0  Basketball  National Basketball Association
# 1          Marquette  6796117.0  Basketball  National Basketball Association
# 2  Boston University        NaN  Basketball  National Basketball Association

# %%
nba.drop(['Sport','League'],axis =1, inplace =True)

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.insert(3,column= 'Sport', value = 'Basketball')

# %%
nba.head(3)
# Out:
#             Name            Team  Number       Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
#
#    Weight            College     Salary
# 0   180.0              Texas  7730337.0
# 1   235.0          Marquette  6796117.0
# 2   205.0  Boston University        NaN

# %%
nba.insert(4,column='Leage',value='NBA')

# %%
nba.head()
# Out:
#             Name            Team  Number       Sport Leage Position   Age  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball   NBA       PG  25.0
# 1    Jae Crowder  Boston Celtics    99.0  Basketball   NBA       SF  25.0
# 2   John Holland  Boston Celtics    30.0  Basketball   NBA       SG  27.0
# 3    R.J. Hunter  Boston Celtics    28.0  Basketball   NBA       SG  22.0
# 4  Jonas Jerebko  Boston Celtics     8.0  Basketball   NBA       PF  29.0
#
#   Height  Weight            College     Salary
# 0    6-2   180.0              Texas  7730337.0
# 1    6-6   235.0          Marquette  6796117.0
# 2    6-5   205.0  Boston University        NaN
# 3    6-5   185.0      Georgia State  1148640.0
# 4   6-10   231.0                NaN  5000000.0

# %% [markdown]
# ### Broadcasting Operations

# %%
nba['Age'].add(5).head()
# Out:
# 0    30.0
# 1    30.0
# 2    32.0
# 3    27.0
# 4    34.0
# Name: Age, dtype: float64

# %%
nba['Age'] = 5

# %%
nba.head(1)
# Out:
#             Name            Team  Number       Sport Leage Position  Age  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball   NBA       PG    5
#
#   Height  Weight College     Salary
# 0    6-2   180.0   Texas  7730337.0

# %%
nba['Age'] - 5
nba.head(1)
# Out:
#             Name            Team  Number       Sport Leage Position  Age  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball   NBA       PG    5
#
#   Height  Weight College     Salary
# 0    6-2   180.0   Texas  7730337.0

# %%
nba['Weigh KG'] = round(nba['Weight'].mul(.453592),0)

# %%
nba.head(3)
# Out:
#             Name            Team  Number       Sport Leage Position  Age  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball   NBA       PG    5
# 1    Jae Crowder  Boston Celtics    99.0  Basketball   NBA       SF    5
# 2   John Holland  Boston Celtics    30.0  Basketball   NBA       SG    5
#
#   Height  Weight            College     Salary  Weigh KG
# 0    6-2   180.0              Texas  7730337.0      82.0
# 1    6-6   235.0          Marquette  6796117.0     107.0
# 2    6-5   205.0  Boston University        NaN      93.0

# %%
nba['Salary in Millions'] =nba['Salary'].div(1000000)

# %% [markdown]
# ### A Review of the .value_counts() Method

# %%
nba["Team"].value_counts().head()
# Out:
# New Orleans Pelicans    19
# Memphis Grizzlies       18
# New York Knicks         16
# Milwaukee Bucks         16
# Phoenix Suns            15
# Name: Team, dtype: int64

# %%
nba['College'].value_counts().head()
# Out:
# Kentucky          22
# Duke              20
# Kansas            18
# North Carolina    16
# UCLA              15
# Name: College, dtype: int64

# %%
nba['College'] = 'Oklahoma'
#This overwrote the existing values for college

# %%
nba.head()
# Out:
#             Name            Team  Number       Sport Leage Position  Age  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball   NBA       PG    5
# 1    Jae Crowder  Boston Celtics    99.0  Basketball   NBA       SF    5
# 2   John Holland  Boston Celtics    30.0  Basketball   NBA       SG    5
# 3    R.J. Hunter  Boston Celtics    28.0  Basketball   NBA       SG    5
# 4  Jonas Jerebko  Boston Celtics     8.0  Basketball   NBA       PF    5
#
#   Height  Weight   College     Salary  Weigh KG  Salary in Millions
# 0    6-2   180.0  Oklahoma  7730337.0      82.0            7.730337
# 1    6-6   235.0  Oklahoma  6796117.0     107.0            6.796117
# 2    6-5   205.0  Oklahoma        NaN      93.0                 NaN
# 3    6-5   185.0  Oklahoma  1148640.0      84.0            1.148640
# 4   6-10   231.0  Oklahoma  5000000.0     105.0            5.000000

# %%
nba = pd.read_csv('nba.csv')

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba['College'].value_counts().head()
# Out:
# Kentucky          22
# Duke              20
# Kansas            18
# North Carolina    16
# UCLA              15
# Name: College, dtype: int64

# %% [markdown]
# ### Drop Rows with Null Values

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.dropna().tail()
#removes any rows that contain null values. See the How parameter
#Review parameters to remove columns, or Any and All Values
# Out:
#               Name       Team  Number Position   Age Height  Weight   College  \
# 449    Rodney Hood  Utah Jazz     5.0       SG  23.0    6-8   206.0      Duke
# 451  Chris Johnson  Utah Jazz    23.0       SF  26.0    6-6   206.0    Dayton
# 452     Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453   Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 456    Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary
# 449  1348440.0
# 451   981348.0
# 452  2239800.0
# 453  2433333.0
# 456   947276.0

# %%
nba.dropna(subset=['Salary']).head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
#
#          College      Salary
# 0          Texas   7730337.0
# 1      Marquette   6796117.0
# 3  Georgia State   1148640.0
# 4            NaN   5000000.0
# 5            NaN  12000000.0

# %%
nba.dropna(subset=['Salary','College']).head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
#
#          College     Salary
# 0          Texas  7730337.0
# 1      Marquette  6796117.0
# 3  Georgia State  1148640.0
# 6            LSU  1170960.0
# 7        Gonzaga  2165160.0

# %% [markdown]
# ### Fill in Null Values with the .fillna() Method

# %%
nba.fillna(value=0).head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4                  0  5000000.0

# %%
nba['Salary'].fillna(0,inplace=True)

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba['College'].fillna("No College", inplace =True)
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4         No College  5000000.0

# %% [markdown]
# ### The .astype() Method

# %%
nba = pd.read_csv("nba.csv").dropna()
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#          College     Salary
# 0          Texas  7730337.0
# 1      Marquette  6796117.0
# 3  Georgia State  1148640.0

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 364 entries, 0 to 456
# Data columns (total 9 columns):
# Name        364 non-null object
# Team        364 non-null object
# Number      364 non-null float64
# Position    364 non-null object
# Age         364 non-null float64
# Height      364 non-null object
# Weight      364 non-null float64
# College     364 non-null object
# Salary      364 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 28.4+ KB

# %%
nba['Salary'].astype('int').head()
# Out:
# 0    7730337
# 1    6796117
# 3    1148640
# 6    1170960
# 7    2165160
# Name: Salary, dtype: int32

# %%
nba['Salary'] = nba["Salary"].astype('int')

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#          College   Salary
# 0          Texas  7730337
# 1      Marquette  6796117
# 3  Georgia State  1148640

# %%
nba['Number']=nba['Number'].astype('int')

# %%
nba['Age']=nba['Age'].astype('int')
nba['Weight'] = nba['Weight'].astype('int')

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2     180
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6     235
# 3    R.J. Hunter  Boston Celtics      28       SG   22    6-5     185
#
#          College   Salary
# 0          Texas  7730337
# 1      Marquette  6796117
# 3  Georgia State  1148640

# %%
nba['Position'].nunique()
# Out:
# 5

# %%
nba['Position'].astype("category")
# Out:
# 0      PG
# 1      SF
# 3      SG
# 6      PF
# 7       C
# 8      PG
# 9      PG
# 10      C
# 11     PG
# 12     SG
# 13     SG
# 14      C
# 16     SG
# 17     SG
# 18     SG
# 19     PG
# 21     SG
# 22     PG
# 23      C
# 24     PF
# 25     PF
# 26     PF
# 27      C
# 28     PG
# 29     PF
# 30     SG
# 31     PF
# 33     SF
# 35     SF
# 36     SG
#        ..
# 422    PG
# 423    SG
# 424    SF
# 425    SG
# 426    PG
# 427    PF
# 428    SF
# 429    SG
# 430    SG
# 431     C
# 432    SF
# 433    SG
# 434     C
# 435    PF
# 436    PG
# 437    SG
# 438    SG
# 439     C
# 440    PG
# 441    PF
# 442    PF
# 443    PG
# 444    SG
# 446    PF
# 448    SF
# 449    SG
# 451    SF
# 452    PF
# 453    PG
# 456     C
# Name: Position, Length: 364, dtype: category
# Categories (5, object): [C, PF, PG, SF, SG]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 364 entries, 0 to 456
# Data columns (total 9 columns):
# Name        364 non-null object
# Team        364 non-null object
# Number      364 non-null int32
# Position    364 non-null object
# Age         364 non-null int32
# Height      364 non-null object
# Weight      364 non-null int32
# College     364 non-null object
# Salary      364 non-null int32
# dtypes: int32(4), object(5)
# memory usage: 32.8+ KB

# %% [markdown]
# ###  Sort a DataFrame with the .sort_values() Method, Part 1

# %%
nba.head()
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2     180
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6     235
# 3    R.J. Hunter  Boston Celtics      28       SG   22    6-5     185
# 6  Jordan Mickey  Boston Celtics      55       PF   21    6-8     235
# 7   Kelly Olynyk  Boston Celtics      41        C   25    7-0     238
#
#          College   Salary
# 0          Texas  7730337
# 1      Marquette  6796117
# 3  Georgia State  1148640
# 6            LSU  1170960
# 7        Gonzaga  2165160

# %%
nba.sort_values('Name',ascending = False).head()
# Out:
#                     Name                    Team  Number Position  Age Height  \
# 271        Zach Randolph       Memphis Grizzlies      50       PF   34    6-9
# 402          Zach LaVine  Minnesota Timberwolves       8       PG   21    6-5
# 386      Wilson Chandler          Denver Nuggets      21       SF   29    6-8
# 25           Willie Reed           Brooklyn Nets      33       PF   26   6-10
# 141  Willie Cauley-Stein        Sacramento Kings       0        C   22    7-0
#
#      Weight         College    Salary
# 271     260  Michigan State   9638555
# 402     189            UCLA   2148360
# 386     225          DePaul  10449438
# 25      220     Saint Louis    947276
# 141     240        Kentucky   3398280

# %%
nba.sort_values("Age").head()
# Out:
#                 Name                    Team  Number Position  Age Height  \
# 226    Rashad Vaughn         Milwaukee Bucks      20       SG   19    6-6
# 122     Devin Booker            Phoenix Suns       1       SG   19    6-6
# 401       Tyus Jones  Minnesota Timberwolves       1       PG   20    6-2
# 85      Kevon Looney   Golden State Warriors      36       SF   20    6-9
# 377  Kelly Oubre Jr.      Washington Wizards      12       SF   20    6-7
#
#      Weight   College   Salary
# 226     202      UNLV  1733040
# 122     206  Kentucky  2127840
# 401     195      Duke  1282080
# 85      220      UCLA  1131960
# 377     205    Kansas  1920240

# %%
nba.sort_values("Age",ascending=False).head()
# Out:
#               Name                   Team  Number Position  Age Height  \
# 298     Tim Duncan      San Antonio Spurs      21        C   40   6-11
# 304   Andre Miller      San Antonio Spurs      24       PG   40    6-3
# 261   Vince Carter      Memphis Grizzlies      15       SG   39    6-6
# 256    Jason Terry        Houston Rockets      31       SG   38    6-2
# 420  Nazr Mohammed  Oklahoma City Thunder      13        C   38   6-10
#
#      Weight         College   Salary
# 298     250     Wake Forest  5250000
# 304     200            Utah   250750
# 261     220  North Carolina  4088019
# 256     185         Arizona   947276
# 420     250        Kentucky   222888

# %%
nba.sort_values("Salary",ascending=False).head()
# Out:
#                 Name                   Team  Number Position  Age Height  \
# 33   Carmelo Anthony        New York Knicks       7       SF   32    6-8
# 339       Chris Bosh             Miami Heat       1       PF   32   6-11
# 100       Chris Paul   Los Angeles Clippers       3       PG   31    6-0
# 414     Kevin Durant  Oklahoma City Thunder      35       SF   27    6-9
# 164     Derrick Rose          Chicago Bulls       1       PG   27    6-3
#
#      Weight       College    Salary
# 33      240      Syracuse  22875000
# 339     235  Georgia Tech  22192730
# 100     175   Wake Forest  21468695
# 414     240         Texas  20158622
# 164     190       Memphis  20093064

# %%
nba.sort_values("Salary",ascending=False).tail()
# Out:
#                 Name                  Team  Number Position  Age Height  \
# 92        Jeff Ayres  Los Angeles Clippers      19       PF   29    6-9
# 175     Jordan McRae   Cleveland Cavaliers      12       SG   25    6-5
# 135    Alan Williams          Phoenix Suns      15        C   23    6-8
# 291  Orlando Johnson  New Orleans Pelicans       0       SG   27    6-5
# 130     Phil Pressey          Phoenix Suns      25       PG   25   5-11
#
#      Weight           College  Salary
# 92      250     Arizona State  111444
# 175     179         Tennessee  111196
# 135     260  UC Santa Barbara   83397
# 291     220  UC Santa Barbara   55722
# 130     175          Missouri   55722

# %% [markdown]
# ###  DataFrame with the .sort_values() Method, Part 2

# %%
nba = pd.read_csv('nba.csv')

# %%
nba.sort_values(['Team','Name']).head()
# Out:
#                 Name           Team  Number Position   Age Height  Weight  \
# 312       Al Horford  Atlanta Hawks    15.0        C  30.0   6-10   245.0
# 318  Dennis Schroder  Atlanta Hawks    17.0       PG  22.0    6-1   172.0
# 323      Jeff Teague  Atlanta Hawks     0.0       PG  27.0    6-2   186.0
# 309    Kent Bazemore  Atlanta Hawks    24.0       SF  26.0    6-5   201.0
# 311     Kirk Hinrich  Atlanta Hawks    12.0       SG  35.0    6-4   190.0
#
#           College      Salary
# 312       Florida  12000000.0
# 318           NaN   1763400.0
# 323   Wake Forest   8000000.0
# 309  Old Dominion   2000000.0
# 311        Kansas   2854940.0

# %%
nba.sort_values(['Team','Name'],ascending = False).head()
# Out:
#                 Name                Team  Number Position   Age Height  \
# 379   Ramon Sessions  Washington Wizards     7.0       PG  30.0    6-3
# 378  Otto Porter Jr.  Washington Wizards    22.0       SF  23.0    6-8
# 375     Nene Hilario  Washington Wizards    42.0        C  33.0   6-11
# 376  Markieff Morris  Washington Wizards     5.0       PF  26.0   6-10
# 381  Marcus Thornton  Washington Wizards    15.0       SF  29.0    6-4
#
#      Weight     College      Salary
# 379   190.0      Nevada   2170465.0
# 378   198.0  Georgetown   4662960.0
# 375   250.0         NaN  13000000.0
# 376   245.0      Kansas   8000000.0
# 381   205.0         LSU    200600.0

# %%
nba.sort_values(['Team','Name'], ascending = [True, False]).head()
# Out:
#                  Name           Team  Number Position   Age Height  Weight  \
# 322    Walter Tavares  Atlanta Hawks    22.0        C  24.0    7-3   260.0
# 310  Tim Hardaway Jr.  Atlanta Hawks    10.0       SG  24.0    6-6   205.0
# 321    Tiago Splitter  Atlanta Hawks    11.0        C  31.0   6-11   245.0
# 320   Thabo Sefolosha  Atlanta Hawks    25.0       SF  32.0    6-7   220.0
# 315      Paul Millsap  Atlanta Hawks     4.0       PF  31.0    6-8   246.0
#
#             College      Salary
# 322             NaN   1000000.0
# 310        Michigan   1304520.0
# 321             NaN   9756250.0
# 320             NaN   4000000.0
# 315  Louisiana Tech  18671659.0

# %% [markdown]
# ###  Sort DataFrame with the .sort_index() Method

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.sort_values(['Number','Salary','Name'], inplace = True)
nba.tail()
# Out:
#                Name                Team  Number Position   Age Height  Weight  \
# 372     Drew Gooden  Washington Wizards    90.0       PF  34.0   6-10   250.0
# 5      Amir Johnson      Boston Celtics    90.0       PF  29.0    6-9   240.0
# 68   Lucas Nogueira     Toronto Raptors    92.0        C  23.0    7-0   220.0
# 1       Jae Crowder      Boston Celtics    99.0       SF  25.0    6-6   235.0
# 457             NaN                 NaN     NaN      NaN   NaN    NaN     NaN
#
#        College      Salary
# 372     Kansas   3300000.0
# 5          NaN  12000000.0
# 68         NaN   1842000.0
# 1    Marquette   6796117.0
# 457        NaN         NaN

# %%
nba.sort_index().head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# ###  Rank Values with the .rank() Method

# %%
nba = pd.read_csv('nba.csv').dropna(how='all')
nba['Salary'] = nba['Salary'].fillna(0).astype('int')
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0
# 3      Georgia State  1148640
# 4                NaN  5000000

# %%
nba['Salary Rank'] = nba['Salary'].rank(ascending=False).astype('int')

# %%
nba.sort_values('Salary', ascending=False).head()
# Out:
#                 Name                 Team  Number Position   Age Height  \
# 109      Kobe Bryant   Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James  Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony      New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard      Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh           Miami Heat     1.0       PF  32.0   6-11
#
#      Weight       College    Salary  Salary Rank
# 109   212.0           NaN  25000000            1
# 169   250.0           NaN  22970500            2
# 33    240.0      Syracuse  22875000            3
# 251   265.0           NaN  22359364            4
# 339   235.0  Georgia Tech  22192730            5
