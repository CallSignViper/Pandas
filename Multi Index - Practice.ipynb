# %%
import pandas as pd

# %%
bigmac = pd.read_csv('bigmac.csv',parse_dates=['Date'])

# %%
bigmac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 3 columns):
# Date                   652 non-null datetime64[ns]
# Country                652 non-null object
# Price in US Dollars    652 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 15.4+ KB

# %%
bigmac.describe()
# Out:
#        Price in US Dollars
# count           652.000000
# mean              3.742853
# std               1.288534
# min               0.660000
# 25%               2.730000
# 50%               3.650000
# 75%               4.540000
# max               9.080000

# %%
bigmac.set_index(keys=['Date','Country'],inplace=True)

# %%
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Brazil                    3.35

# %%
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.index.names
# Out:
# FrozenList(['Date', 'Country'])

# %%
type(bigmac.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
bigmac.index[0]
# Out:
# (Timestamp('2010-01-01 00:00:00'), 'Argentina')

# %% [markdown]
# ### The .get_level_values() Method

# %%
bigmac = pd.read_csv('bigmac.csv',parse_dates=['Date'],index_col=['Date','Country'])
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.index.get_level_values(0)
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01',
#                ...
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01'],
#               dtype='datetime64[ns]', name='Date', length=652, freq=None)

# %%
bigmac.index.get_level_values(1)
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Czech Republic',
#        ...
#        'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'UAE', 'Ukraine',
#        'United States', 'Uruguay', 'Venezuela', 'Vietnam'],
#       dtype='object', name='Country', length=652)

# %%
bigmac.index.get_level_values('Date')
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01',
#                ...
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01'],
#               dtype='datetime64[ns]', name='Date', length=652, freq=None)

# %%
bigmac.index.get_level_values('Country')
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Czech Republic',
#        ...
#        'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'UAE', 'Ukraine',
#        'United States', 'Uruguay', 'Venezuela', 'Vietnam'],
#       dtype='object', name='Country', length=652)

# %% [markdown]
# ###  The .set_names() Method on MultiIndex

# %%
bigmac.index.set_names(["Date","Location"],inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Location
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %% [markdown]
# ### Sort Index

# %%
bigmac.sort_index(ascending=[True,False]).head()
# Out:
#                           Price in US Dollars
# Date       Location
# 2010-01-01 Uruguay                       3.32
#            United States                 3.58
#            Ukraine                       1.83
#            UAE                           2.99
#            Turkey                        3.83

# %% [markdown]
# ### Extract Rows from a Multi Index Data Frame

# %%
bigmac.loc[('2010-01-01','Brazil'),'Price in US Dollars']
# Out:
# Date        Location
# 2010-01-01  Brazil      4.76
# Name: Price in US Dollars, dtype: float64

# %%
bigmac.loc[('2015-01-01','Chile'),'Price in US Dollars']
# Out:
# Date        Location
# 2015-01-01  Chile       3.35
# Name: Price in US Dollars, dtype: float64

# %% [markdown]
# ### The .transpose() Method

# %%
bigmac.transpose()
# Out:
# Date                2010-01-01                                              \
# Location             Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                     ...    2016-01-01  \
# Location            Colombia Costa Rica Czech Republic   ...   Switzerland
# Price in US Dollars     3.91       3.52           3.71   ...          6.44
#
# Date                                                                    \
# Location            Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Location            Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %% [markdown]
# ### The .swaplevel() Method

# %%
bigmac.swaplevel().head()
# Out:
#                       Price in US Dollars
# Location  Date
# Argentina 2010-01-01                 1.84
# Australia 2010-01-01                 3.98
# Brazil    2010-01-01                 4.76
# Britain   2010-01-01                 3.67
# Canada    2010-01-01                 3.97

# %% [markdown]
# ### The .stack() Method

# %%
worldstats = pd.read_csv('worldstats.csv', index_col=['country','year'])

# %%
worldstats.head()
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12
#            2012  368802611.0  2.773270e+12
#            2011  361031820.0  2.497945e+12

# %%
worldstats.stack()
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
#                   GDP           2.873600e+12
#             2013  Population    3.765043e+08
#                   GDP           2.846994e+12
#             2012  Population    3.688026e+08
#                   GDP           2.773270e+12
#             2011  Population    3.610318e+08
#                   GDP           2.497945e+12
#             2010  Population    3.531122e+08
#                   GDP           2.103825e+12
#             2009  Population    3.450542e+08
#                   GDP           1.798878e+12
#             2008  Population    3.368865e+08
#                   GDP           2.081343e+12
#             2007  Population    3.287666e+08
#                   GDP           1.641666e+12
#             2006  Population    3.209067e+08
#                   GDP           1.404190e+12
# ...

# %%
s = worldstats.stack().to_frame().head()
s
# Out:
#                                        0
# country    year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08

# %% [markdown]
# ### The .unstack() Method, Part 1

# %%
s.unstack().unstack().unstack()
# Out:
#                year  country
# 0  Population  2013  Arab World    3.765043e+08
#                2014  Arab World    3.842226e+08
#                2015  Arab World    3.920223e+08
#    GDP         2013  Arab World             NaN
#                2014  Arab World    2.873600e+12
#                2015  Arab World    2.530102e+12
# dtype: float64

# %%
world = pd.read_csv('worldstats.csv',index_col=['country','year'])
world.head(3)
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12

# %%
s=world.stack()
s.head(3)
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
# dtype: float64

# %%
s.unstack(0).head()
# Out:
# country           Afghanistan  Albania       Algeria  Andorra  Angola  \
# year
# 1960 Population  8.994793e+06      NaN  1.112489e+07      NaN     NaN
#      GDP         5.377778e+08      NaN  2.723638e+09      NaN     NaN
# 1961 Population  9.164945e+06      NaN  1.140486e+07      NaN     NaN
#      GDP         5.488889e+08      NaN  2.434767e+09      NaN     NaN
# 1962 Population  9.343772e+06      NaN  1.169015e+07      NaN     NaN
#
# country          Antigua and Barbuda  Arab World   Argentina  Armenia  Aruba  \
# year
# 1960 Population                  NaN         NaN         NaN      NaN    NaN
#      GDP                         NaN         NaN         NaN      NaN    NaN
# 1961 Population                  NaN         NaN         NaN      NaN    NaN
#      GDP                         NaN         NaN         NaN      NaN    NaN
# 1962 Population                  NaN         NaN  21287682.0      NaN    NaN
#
# ...

# %%
s.unstack(1).head()
# Out:
# year                            1960          1961          1962  \
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.112489e+07  1.140486e+07  1.169015e+07
#
# year                            1963          1964          1965  \
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
#             GDP         7.511112e+08  8.000000e+08  1.006667e+09
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.198513e+07  1.229597e+07  1.262695e+07
#
# year                            1966          1967          1968  \
# country
# Afghanistan Population  1.014884e+07  1.036860e+07  1.059979e+07
# ...

# %%
s.unstack(2).head()
# Out:
#                   Population           GDP
# country     year
# Afghanistan 1960   8994793.0  5.377778e+08
#             1961   9164945.0  5.488889e+08
#             1962   9343772.0  5.466667e+08
#             1963   9531555.0  7.511112e+08
#             1964   9728645.0  8.000000e+08

# %%
s.unstack(-2).head()
# Out:
# year                            1960          1961          1962  \
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.112489e+07  1.140486e+07  1.169015e+07
#
# year                            1963          1964          1965  \
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
#             GDP         7.511112e+08  8.000000e+08  1.006667e+09
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.198513e+07  1.229597e+07  1.262695e+07
#
# year                            1966          1967          1968  \
# country
# Afghanistan Population  1.014884e+07  1.036860e+07  1.059979e+07
# ...

# %%
s.unstack(-3).head()
# Out:
# country           Afghanistan  Albania       Algeria  Andorra  Angola  \
# year
# 1960 Population  8.994793e+06      NaN  1.112489e+07      NaN     NaN
#      GDP         5.377778e+08      NaN  2.723638e+09      NaN     NaN
# 1961 Population  9.164945e+06      NaN  1.140486e+07      NaN     NaN
#      GDP         5.488889e+08      NaN  2.434767e+09      NaN     NaN
# 1962 Population  9.343772e+06      NaN  1.169015e+07      NaN     NaN
#
# country          Antigua and Barbuda  Arab World   Argentina  Armenia  Aruba  \
# year
# 1960 Population                  NaN         NaN         NaN      NaN    NaN
#      GDP                         NaN         NaN         NaN      NaN    NaN
# 1961 Population                  NaN         NaN         NaN      NaN    NaN
#      GDP                         NaN         NaN         NaN      NaN    NaN
# 1962 Population                  NaN         NaN  21287682.0      NaN    NaN
#
# ...

# %%
s.unstack('year').head()
# Out:
# year                            1960          1961          1962  \
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.112489e+07  1.140486e+07  1.169015e+07
#
# year                            1963          1964          1965  \
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
#             GDP         7.511112e+08  8.000000e+08  1.006667e+09
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.198513e+07  1.229597e+07  1.262695e+07
#
# year                            1966          1967          1968  \
# country
# Afghanistan Population  1.014884e+07  1.036860e+07  1.059979e+07
# ...

# %%
s.unstack('country').head()
# Out:
# country           Afghanistan  Albania       Algeria  Andorra  Angola  \
# year
# 1960 Population  8.994793e+06      NaN  1.112489e+07      NaN     NaN
#      GDP         5.377778e+08      NaN  2.723638e+09      NaN     NaN
# 1961 Population  9.164945e+06      NaN  1.140486e+07      NaN     NaN
#      GDP         5.488889e+08      NaN  2.434767e+09      NaN     NaN
# 1962 Population  9.343772e+06      NaN  1.169015e+07      NaN     NaN
#
# country          Antigua and Barbuda  Arab World   Argentina  Armenia  Aruba  \
# year
# 1960 Population                  NaN         NaN         NaN      NaN    NaN
#      GDP                         NaN         NaN         NaN      NaN    NaN
# 1961 Population                  NaN         NaN         NaN      NaN    NaN
#      GDP                         NaN         NaN         NaN      NaN    NaN
# 1962 Population                  NaN         NaN  21287682.0      NaN    NaN
#
# ...

# %%
s.unstack(level= [1,0])
# Out:
# year                2015          2014          2013          2012  \
# country       Arab World    Arab World    Arab World    Arab World
# Population  3.920223e+08  3.842226e+08  3.765043e+08  3.688026e+08
# GDP         2.530102e+12  2.873600e+12  2.846994e+12  2.773270e+12
#
# year                2011          2010          2009          2008  \
# country       Arab World    Arab World    Arab World    Arab World
# Population  3.610318e+08  3.531122e+08  3.450542e+08  3.368865e+08
# GDP         2.497945e+12  2.103825e+12  1.798878e+12  2.081343e+12
#
# year                2007          2006      ...               1969  \
# country       Arab World    Arab World      ...           Zimbabwe
# Population  3.287666e+08  3.209067e+08      ...       5.036321e+06
# GDP         1.641666e+12  1.404190e+12      ...       1.747999e+09
#
# year                1968          1967          1966          1965  \
# country         Zimbabwe      Zimbabwe      Zimbabwe      Zimbabwe
# ...

# %%
s.unstack(level= ['country',1])
# Out:
# country       Arab World                                            \
# year                2015          2014          2013          2012
# Population  3.920223e+08  3.842226e+08  3.765043e+08  3.688026e+08
# GDP         2.530102e+12  2.873600e+12  2.846994e+12  2.773270e+12
#
# country                                                             \
# year                2011          2010          2009          2008
# Population  3.610318e+08  3.531122e+08  3.450542e+08  3.368865e+08
# GDP         2.497945e+12  2.103825e+12  1.798878e+12  2.081343e+12
#
# country                                     ...           Zimbabwe  \
# year                2007          2006      ...               1969
# Population  3.287666e+08  3.209067e+08      ...       5.036321e+06
# GDP         1.641666e+12  1.404190e+12      ...       1.747999e+09
#
# country                                                             \
# year                1968          1967          1966          1965
# ...

# %% [markdown]
# ### The Pivot Method

# %%
sales = pd.read_csv('salesmen.csv',parse_dates=['Date'])
sales['Salesman'] = sales['Salesman'].astype('category')
sales.head(3)
# Out:
#         Date Salesman  Revenue
# 0 2016-01-01      Bob     7172
# 1 2016-01-02      Bob     6362
# 2 2016-01-03      Bob     5982

# %%
len(sales)
# Out:
# 1830

# %%
sales['Salesman'].value_counts()
# Out:
# Ronald    366
# Oscar     366
# Jeb       366
# Dave      366
# Bob       366
# Name: Salesman, dtype: int64

# %%
sales.pivot(index='Date',columns='Salesman',values='Revenue').head()
# Out:
# Salesman     Bob  Dave   Jeb  Oscar  Ronald
# Date
# 2016-01-01  7172  1864  4430   5250    2639
# 2016-01-02  6362  8278  8026   8661    4951
# 2016-01-03  5982  4226  5188   7075    2703
# 2016-01-04  7917  3868  3144   2524    4258
# 2016-01-05  7837  2287   938   2793    7771

# %% [markdown]
# ### The pivot_table() Method

# %%
foods = pd.read_csv('foods.csv')

# %%
foods.pivot_table(values='Spend',index='Gender',aggfunc='sum')
# Out:
#            Spend
# Gender
# Female  25963.33
# Male    24106.04

# %%
foods.pivot_table(values='Spend',index=['Gender','Item'],aggfunc='sum')
# Out:
#                     Spend
# Gender Item
# Female Burger     4094.30
#        Burrito    4257.82
#        Chalupa    4152.26
#        Donut      4743.00
#        Ice Cream  4032.87
#        Sushi      4683.08
# Male   Burger     3671.43
#        Burrito    4012.62
#        Chalupa    3492.26
#        Donut      4015.76
#        Ice Cream  4854.12
#        Sushi      4059.85

# %%
foods.pivot_table(values='Spend',index=['Gender','Item'],columns='City',aggfunc='sum')
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger      1239.04       1639.24   1216.02
#        Burrito      978.95       1458.76   1820.11
#        Chalupa      876.58       1673.33   1602.35
#        Donut       1446.78       1639.26   1656.96
#        Ice Cream   1521.62       1479.22   1032.03
#        Sushi       1480.29       1742.88   1459.91
# Male   Burger      1294.09        938.18   1439.16
#        Burrito     1399.40       1312.93   1300.29
#        Chalupa     1227.77       1114.23   1150.26
#        Donut       1345.27       1249.36   1421.13
#        Ice Cream   1603.63       2191.27   1059.22
#        Sushi       1396.15       1395.88   1267.82

# %%
foods.pivot_table(values='Spend',index=['Gender','Item'],columns=['Frequency','City'],aggfunc='count')
# Out:
# Frequency           Daily                        Monthly               \
# City             New York Philadelphia Stamford New York Philadelphia
# Gender Item
# Female Burger         6.0          3.0      3.0      3.0          4.0
#        Burrito        5.0          6.0      5.0      3.0          2.0
#        Chalupa        1.0          1.0      1.0      2.0          4.0
#        Donut         12.0          4.0      3.0      4.0          1.0
#        Ice Cream      4.0          3.0      2.0      2.0          2.0
#        Sushi          2.0          6.0      7.0      2.0          1.0
# Male   Burger         5.0          3.0      4.0      3.0          3.0
#        Burrito        3.0          4.0      4.0      3.0          3.0
#        Chalupa        2.0          4.0      4.0      5.0          2.0
#        Donut          5.0          4.0      2.0      4.0          5.0
#        Ice Cream      3.0          5.0      1.0      3.0          6.0
# ...

# %% [markdown]
# ### The pd.melt() Method - Reverse Pivot

# %%
sales = pd.read_csv('quarters.csv')
sales
# Out:
#   Salesman      Q1      Q2      Q3      Q4
# 0    Boris  602908  233879  354479   32704
# 1      Bob   43790  514863  297151  544493
# 2    Tommy  392668  113579  430882  247231
# 3   Travis  834663  266785  749238  570524
# 4   Donald  580935  411379  110390  651572
# 5      Ted  656644   70803  375948  321388
# 6      Jeb  486141  600753  742716  404995
# 7    Stacy  479662  742806  770712    2501
# 8   Morgan  992673  879183   37945  293710

# %%
pd.melt(sales,id_vars='Salesman',var_name='Quarter', value_name = 'Revenue')
# Out:
#    Salesman Quarter  Revenue
# 0     Boris      Q1   602908
# 1       Bob      Q1    43790
# 2     Tommy      Q1   392668
# 3    Travis      Q1   834663
# 4    Donald      Q1   580935
# 5       Ted      Q1   656644
# 6       Jeb      Q1   486141
# 7     Stacy      Q1   479662
# 8    Morgan      Q1   992673
# 9     Boris      Q2   233879
# 10      Bob      Q2   514863
# 11    Tommy      Q2   113579
# 12   Travis      Q2   266785
# 13   Donald      Q2   411379
# 14      Ted      Q2    70803
# 15      Jeb      Q2   600753
# 16    Stacy      Q2   742806
# 17   Morgan      Q2   879183
# 18    Boris      Q3   354479
# 19      Bob      Q3   297151
# 20    Tommy      Q3   430882
# 21   Travis      Q3   749238
# 22   Donald      Q3   110390
# 23      Ted      Q3   375948
# 24      Jeb      Q3   742716
# 25    Stacy      Q3   770712
# 26   Morgan      Q3    37945
# 27    Boris      Q4    32704
# 28      Bob      Q4   544493
# 29    Tommy      Q4   247231
# 30   Travis      Q4   570524
# ...
